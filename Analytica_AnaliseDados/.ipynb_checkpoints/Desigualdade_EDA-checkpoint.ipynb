# %% [markdown]
# ## Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="darkgrid")
sns.set_palette("Spectral")

# %% [markdown]
# ## Leitura de CSV's

# %%
sm = pd.read_csv('salariominimo_vigente.csv')
ind_soc = pd.read_csv('indsoc.csv')
ipca = pd.read_csv('ipca.csv')
inpc = pd.read_csv('inpc.csv')

# %% [markdown]
# ## Análise incial das tabelas e formatação

# %%
sma2021 = sm[sm['Data'] < 2021.01].index
sma2021f = sm[sm['Data'] > 2021.12].index
sm2021d = sm.drop(sma2021)
sm2021fd = sm2021d.drop(sma2021f)
smdrop = sm2021fd.drop(['Unnamed: 2'], axis=1)

# %%
smdrop.head()
# Out:
#         Data  \
# 966  2021.01
# 967  2021.02
# 968  2021.03
# 969  2021.04
# 970  2021.05
#
#      Salário mínimo vigente - R$ - Ministério da Economia- Outras (Min. Economia/Outras) - MTE12_SALMIN12
# 966                                             1100.0
# 967                                             1100.0
# 968                                             1100.0
# 969                                             1100.0
# 970                                             1100.0

# %%
indsocdrop = ind_soc.drop(['UF'], axis=1)
indsocdrop.head()
# Out:
#   Nome da UF   Ano  \
# 0   Rondônia  2021
# 1       Acre  2021
# 2   Amazonas  2021
# 3    Roraima  2021
# 4       Pará  2021
#
#    Porcentagem de pessoas com renda domiciliar per capita igual ou inferior a meio salário mínimo  \
# 0                                              31.68
# 1                                              46.08
# 2                                              50.76
# 3                                              45.79
# 4                                              45.60
#
#    Renda per capita
# 0            552.08
# 1            477.19
# 2            433.18
# 3            562.36
# 4            461.93

# %%
ipca2021 = ipca[ipca['ano'] < 2021].index
ipca2021f = ipca[ipca['ano'] > 2021].index	
ipca2021d = ipca.drop(ipca2021)
ipca2021df = ipca2021d.drop(ipca2021f)
ipcadrop1 = ipca2021df.drop(['Unnamed: 0'], axis=1)
ipcadrop = ipcadrop1.drop(['id_categoria_bd'], axis=1)

# %%
ipcadrop.head()
# Out:
#        ano  mes  id_categoria     categoria  peso_mensal  variacao_mensal  \
# 5484  2021    1           NaN  Índice geral        100.0             0.25
# 5485  2021    8           NaN  Índice geral        100.0             0.87
# 5486  2021    9           NaN  Índice geral        100.0             1.16
# 5487  2021   11           NaN  Índice geral        100.0             0.95
# 5488  2021    7           NaN  Índice geral        100.0             0.96
#
#       variacao_anual  variacao_doze_meses
# 5484            0.25                 4.56
# 5485            5.67                 9.68
# 5486            6.90                10.25
# 5487            9.26                10.74
# 5488            4.76                 8.99

# %%
inpc2021 = inpc[inpc['ano'] < 2021].index
inpc2021f = inpc[inpc['ano'] > 2021].index
inpc2021d = inpc.drop(inpc2021)
inpc2021df = inpc2021d.drop(inpc2021f)
inpcdrop1 = inpc2021df.drop(['Unnamed: 0'], axis=1)
inpcdrop = inpcdrop1.drop(['id_categoria_bd'], axis=1)

# %%
inpcdrop.head()
# Out:
#        ano  mes  id_categoria     categoria  peso_mensal  variacao_mensal  \
# 5364  2021   11           NaN  Índice geral        100.0             0.84
# 5365  2021    4           NaN  Índice geral        100.0             0.38
# 5366  2021    1           NaN  Índice geral        100.0             0.27
# 5367  2021    8           NaN  Índice geral        100.0             0.88
# 5368  2021    3           NaN  Índice geral        100.0             0.86
#
#       variacao_anual  variacao_doze_meses
# 5364            9.36                10.96
# 5365            2.35                 7.59
# 5366            0.27                 5.53
# 5367            5.94                10.42
# 5368            1.96                 6.94

# %% [markdown]
# ## Análise exploratória dos dados

# %%
smdrop.describe()
# Out:
#               Data  \
# count    12.000000
# mean   2021.065000
# std       0.036056
# min    2021.010000
# 25%    2021.037500
# 50%    2021.065000
# 75%    2021.092500
# max    2021.120000
#
#        Salário mínimo vigente - R$ - Ministério da Economia- Outras (Min. Economia/Outras) - MTE12_SALMIN12
# count                                               12.0
# mean                                              1100.0
# std                                                  0.0
# min                                               1100.0
# 25%                                               1100.0
# 50%                                               1100.0
# 75%                                               1100.0
# max                                               1100.0

# %%
ind_soc.describe()
# Out:
#               UF     Ano  \
# count  27.000000    27.0
# mean   29.111111  2021.0
# std    13.024631     0.0
# min    11.000000  2021.0
# 25%    19.000000  2021.0
# 50%    27.000000  2021.0
# 75%    38.000000  2021.0
# max    53.000000  2021.0
#
#        Porcentagem de pessoas com renda domiciliar per capita igual ou inferior a meio salário mínimo  \
# count                                          27.000000
# mean                                           34.587407
# std                                            14.577824
# min                                            10.080000
# 25%                                            21.230000
# 50%                                            42.280000
# 75%                                            46.305000
# max                                            57.360000
#
#        Renda per capita
# count          27.00000
# mean          646.27963
# std           243.70981
# min           344.52000
# 25%           460.72000
# ...

# %%
ipcadrop.describe()
# Out:
#           ano          mes  id_categoria  peso_mensal  variacao_mensal  \
# count  5484.0  5484.000000  5.472000e+03  5484.000000      5484.000000
# mean   2021.0     6.500000  2.733959e+06     1.094092         0.712101
# std       0.0     3.452367  2.583377e+06     5.251935         3.150469
# min    2021.0     1.000000  1.000000e+00     0.000300       -32.940000
# 25%    2021.0     3.750000  1.105006e+06     0.022175        -0.010000
# 50%    2021.0     6.500000  1.116003e+06     0.121200         0.510000
# 75%    2021.0     9.250000  5.101001e+06     0.474650         1.340000
# max    2021.0    12.000000  9.101116e+06   100.000000        44.740000
#
#        variacao_anual  variacao_doze_meses
# count     5484.000000          5484.000000
# mean         4.153094             8.951014
# std          8.134958            11.854879
# min        -45.190000           -43.530000
# 25%          0.530000             2.320000
# 50%          2.900000             6.225000
# ...

# %%
inpcdrop.describe()
# Out:
#           ano          mes  id_categoria  peso_mensal  variacao_mensal  \
# count  5364.0  5364.000000  5.352000e+03  5364.000000      5364.000000
# mean   2021.0     6.500000  2.770031e+06     1.118569         0.706810
# std       0.0     3.452374  2.598731e+06     5.327235         2.939298
# min    2021.0     1.000000  1.000000e+00     0.000200       -27.650000
# 25%    2021.0     3.750000  1.105010e+06     0.031700         0.000000
# 50%    2021.0     6.500000  1.116018e+06     0.139200         0.520000
# 75%    2021.0     9.250000  5.101006e+06     0.483375         1.340000
# max    2021.0    12.000000  9.101116e+06   100.000000        44.740000
#
#        variacao_anual  variacao_doze_meses
# count     5364.000000          5364.000000
# mean         4.048609             8.872043
# std          8.191022            11.797892
# min        -44.220000           -40.590000
# 25%          0.510000             2.310000
# 50%          2.980000             6.215000
# ...

# %%
#categoria: alimentação fora de casa
alimentosforaipca = ipcadrop[(ipcadrop['categoria'] == 'Alimentação fora do domicílio') & (ipcadrop['id_categoria'] == 12)]
alimentosforainpc = inpcdrop[(inpcdrop['categoria'] == 'Alimentação fora do domicílio') & (inpcdrop['id_categoria'] == 12)]
alimentosforaipca.insert(0, 'tabela', ['ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca'], allow_duplicates=True)
alimentosforainpc.insert(0, 'tabela', ['inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc'], allow_duplicates=True)
alimentosforaconcat = pd.concat([alimentosforaipca, alimentosforainpc])

# %%
#categoria: alimentos em casa
alimentoscasaipca = ipcadrop[ipcadrop['categoria'] == 'Alimentação no domicílio']
alimentoscasainpc = inpcdrop[inpcdrop['categoria'] == 'Alimentação no domicílio']
alimentoscasaipca.insert(0, 'tabela', ['ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca'], allow_duplicates=True)
alimentoscasainpc.insert(0, 'tabela', ['inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc'], allow_duplicates=True)
alimentoscasaconcat = pd.concat([alimentoscasaipca, alimentoscasainpc])

# %%
#categoria: aluguel
aluguelipca = ipcadrop[ipcadrop['categoria'] == 'Aluguel e taxas']
aluguelinpc = inpcdrop[inpcdrop['categoria'] == 'Aluguel e taxas']
aluguelipca.insert(0, 'tabela', ['ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca'], allow_duplicates=True)
aluguelinpc.insert(0, 'tabela', ['inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc'], allow_duplicates=True)
aluguelconcat = pd.concat([aluguelipca, aluguelinpc])

# %%
#categoria: agua e esgoto
aguaipca = ipcadrop[ipcadrop['categoria'] == 'Taxa de água e esgoto']
aguainpc = inpcdrop[inpcdrop['categoria'] == 'Taxa de água e esgoto']
aguaipca.insert(0, 'tabela', ['ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca'], allow_duplicates=True)
aguainpc.insert(0, 'tabela', ['inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc'], allow_duplicates=True)
aguaconcat = pd.concat([aguaipca, aguainpc])

# %%
#categoria: artigos de limpeza 
artlimpezaipca = ipcadrop[ipcadrop['categoria'] == 'Artigos de limpeza']
artlimpezainpc = inpcdrop[inpcdrop['categoria'] == 'Artigos de limpeza']
artlimpezaipca.insert(0, 'tabela', ['ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca'], allow_duplicates=True)
artlimpezainpc.insert(0, 'tabela', ['inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc'], allow_duplicates=True)
artlimpezaconcat = pd.concat([artlimpezaipca, artlimpezainpc])

# %%
#categoria: gás de botijão
botijaoipca = ipcadrop[ipcadrop['categoria'] == 'Gás de botijão']
botijaoinpc = inpcdrop[inpcdrop['categoria'] == 'Gás de botijão']
botijaoipca.insert(0, 'tabela', ['ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca'], allow_duplicates=True)
botijaoinpc.insert(0, 'tabela', ['inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc'], allow_duplicates=True)
botijaoconcat = pd.concat([botijaoipca, botijaoinpc])

# %%
#categoria: gás encanado
gascanoipca = ipcadrop[ipcadrop['categoria'] == 'Gás encanado']
gascanoinpc = inpcdrop[inpcdrop['categoria'] == 'Gás encanado']
gascanoipca.insert(0, 'tabela', ['ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca'], allow_duplicates=True)
gascanoinpc.insert(0, 'tabela', ['inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc'], allow_duplicates=True)
gascanoconcat = pd.concat([gascanoipca, gascanoinpc])

# %%
#categoria: energia residêncial
energiaipca = ipcadrop[(ipcadrop['categoria'] == 'Energia elétrica residencial') & (ipcadrop['id_categoria'] == 2202)]
energiainpc = inpcdrop[(inpcdrop['categoria'] == 'Energia elétrica residencial') & (inpcdrop['id_categoria'] == 2202)]
energiaipca.insert(0, 'tabela', ['ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca'], allow_duplicates=True)
energiainpc.insert(0, 'tabela', ['inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc'], allow_duplicates=True)
energiaconcat = pd.concat([energiaipca, energiainpc])

# %%
#categoria: roupa
roupaipca = ipcadrop[ipcadrop['categoria'] == 'Roupas']
roupainpc = inpcdrop[inpcdrop['categoria'] == 'Roupas']
roupaipca.insert(0, 'tabela', ['ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca'], allow_duplicates=True)
roupainpc.insert(0, 'tabela', ['inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc'], allow_duplicates=True)
roupaconcat = pd.concat([roupaipca, roupainpc])

# %%
#categoria: transporte publico
transpublicoipca = ipcadrop[ipcadrop['categoria'] == 'Transporte público']
transpublicoinpc = inpcdrop[inpcdrop['categoria'] == 'Transporte público']
transpublicoipca.insert(0, 'tabela', ['ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca'], allow_duplicates=True)
transpublicoinpc.insert(0, 'tabela', ['inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc'], allow_duplicates=True)
transpublicoconcat = pd.concat([transpublicoipca, transpublicoinpc])

# %%
#categoria: produtos farmaceuticos
farmaciaipca = ipcadrop[ipcadrop['categoria'] == 'Produtos farmacêuticos']
farmaciainpc = inpcdrop[inpcdrop['categoria'] == 'Produtos farmacêuticos']
farmaciaipca.insert(0, 'tabela', ['ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca'], allow_duplicates=True)
farmaciainpc.insert(0, 'tabela', ['inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc'], allow_duplicates=True)
farmaciaconcat = pd.concat([farmaciaipca, farmaciainpc])

# %%
#categoria: serviços medicos e dentarios
medicoipca = ipcadrop[ipcadrop['categoria'] == 'Serviços médicos e dentários']
medicoinpc = inpcdrop[inpcdrop['categoria'] == 'Serviços médicos e dentários']
medicoipca.insert(0, 'tabela', ['ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca'], allow_duplicates=True)
medicoinpc.insert(0, 'tabela', ['inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc'], allow_duplicates=True)
medicoconcat = pd.concat([medicoipca, medicoinpc])

# %%
#categoria: higiene pessoal
higieneipca = ipcadrop[ipcadrop['categoria'] == 'Higiene pessoal']
higieneinpc = inpcdrop[inpcdrop['categoria'] == 'Higiene pessoal']
higieneipca.insert(0, 'tabela', ['ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca'], allow_duplicates=True)
higieneinpc.insert(0, 'tabela', ['inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc'], allow_duplicates=True)
higieneconcat = pd.concat([higieneipca, higieneinpc])

# %%
#categoria: educação
educacaoipca = ipcadrop[ipcadrop['categoria'] == 'Educação']
educacaoinpc = inpcdrop[inpcdrop['categoria'] == 'Educação']
educacaoipca.insert(0, 'tabela', ['ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca'], allow_duplicates=True)
educacaoinpc.insert(0, 'tabela', ['inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc'], allow_duplicates=True)
educacaoconcat = pd.concat([educacaoipca, educacaoinpc])

# %%
#categoria: telefonia móvel
telmovelipca = ipcadrop[ipcadrop['categoria'] == 'Plano de telefonia móvel']
telmovelinpc = inpcdrop[inpcdrop['categoria'] == 'Plano de telefonia móvel']
telmovelipca.insert(0, 'tabela', ['ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca'], allow_duplicates=True)
telmovelinpc.insert(0, 'tabela', ['inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc'], allow_duplicates=True)
telmovelconcat = pd.concat([telmovelipca, telmovelinpc])

# %%
#categoria: acesso a internet
internetipca = ipcadrop[ipcadrop['categoria'] == 'Acesso à internet']
internetinpc = inpcdrop[inpcdrop['categoria'] == 'Acesso à internet']
internetipca.insert(0, 'tabela', ['ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca'], allow_duplicates=True)
internetinpc.insert(0, 'tabela', ['inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc'], allow_duplicates=True)
internetconcat = pd.concat([internetipca, internetinpc])

# %%
#tabela de despesas básicas
despesasbasicas = pd.concat([alimentosforaconcat, alimentoscasaconcat, aluguelconcat, aguaconcat, artlimpezaconcat, botijaoconcat, gascanoconcat, energiaconcat, roupaconcat,
                             transpublicoconcat, farmaciaconcat, medicoconcat, higieneconcat, educacaoconcat, telmovelconcat, internetconcat])

# %%
sns.catplot(
    data=despesasbasicas, x="mes", y="peso_mensal", col="categoria", hue="tabela", kind="point", height=6, aspect=.8, col_wrap=4
).set(xticks=range(12))

# %%
despesasbasicas.head()
# Out:
#      tabela   ano  mes  id_categoria                      categoria  \
# 7620   ipca  2021    9          12.0  Alimentação fora do domicílio
# 7621   ipca  2021   11          12.0  Alimentação fora do domicílio
# 7622   ipca  2021    3          12.0  Alimentação fora do domicílio
# 7623   ipca  2021    7          12.0  Alimentação fora do domicílio
# 7624   ipca  2021   10          12.0  Alimentação fora do domicílio
#
#       peso_mensal  variacao_mensal  variacao_anual  variacao_doze_meses
# 7620       5.8439             0.59            5.57                 7.38
# 7621       5.7847            -0.25            6.13                 6.95
# 7622       5.8877             0.89            2.09                 5.33
# 7623       5.8984             0.14            4.16                 6.69
# 7624       5.8112             0.78            6.40                 7.83

# %%
despesasencanado = pd.concat([alimentosforaconcat, alimentoscasaconcat, aluguelconcat, aguaconcat, artlimpezaconcat, gascanoconcat, energiaconcat, roupaconcat,
                             transpublicoconcat, farmaciaconcat, medicoconcat, higieneconcat, educacaoconcat, telmovelconcat, internetconcat])

despesasbotijao = pd.concat([alimentosforaconcat, alimentoscasaconcat, aluguelconcat, aguaconcat, artlimpezaconcat, botijaoconcat, energiaconcat, roupaconcat,
                             transpublicoconcat, farmaciaconcat, medicoconcat, higieneconcat, educacaoconcat, telmovelconcat, internetconcat])

# %%
janba = despesasbotijao.loc[(despesasbotijao['mes'] == 1) & (despesasbotijao['tabela'] == 'ipca'), 'peso_mensal'].sum()
fevba = despesasbotijao.loc[(despesasbotijao['mes'] == 2) & (despesasbotijao['tabela'] == 'ipca'), 'peso_mensal'].sum()
marba = despesasbotijao.loc[(despesasbotijao['mes'] == 3) & (despesasbotijao['tabela'] == 'ipca'), 'peso_mensal'].sum()
abrba = despesasbotijao.loc[(despesasbotijao['mes'] == 4) & (despesasbotijao['tabela'] == 'ipca'), 'peso_mensal'].sum()
maiba = despesasbotijao.loc[(despesasbotijao['mes'] == 5) & (despesasbotijao['tabela'] == 'ipca'), 'peso_mensal'].sum()
junba = despesasbotijao.loc[(despesasbotijao['mes'] == 6) & (despesasbotijao['tabela'] == 'ipca'), 'peso_mensal'].sum()
julba = despesasbotijao.loc[(despesasbotijao['mes'] == 7) & (despesasbotijao['tabela'] == 'ipca'), 'peso_mensal'].sum()
agoba = despesasbotijao.loc[(despesasbotijao['mes'] == 8) & (despesasbotijao['tabela'] == 'ipca'), 'peso_mensal'].sum()
setba = despesasbotijao.loc[(despesasbotijao['mes'] == 9) & (despesasbotijao['tabela'] == 'ipca'), 'peso_mensal'].sum()
outba = despesasbotijao.loc[(despesasbotijao['mes'] == 10) & (despesasbotijao['tabela'] == 'ipca'), 'peso_mensal'].sum()
novba = despesasbotijao.loc[(despesasbotijao['mes'] == 11) & (despesasbotijao['tabela'] == 'ipca'), 'peso_mensal'].sum()
dezba = despesasbotijao.loc[(despesasbotijao['mes'] == 12) & (despesasbotijao['tabela'] == 'ipca'), 'peso_mensal'].sum()

janbc = despesasbotijao.loc[(despesasbotijao['mes'] == 1) & (despesasbotijao['tabela'] == 'inpc'), 'peso_mensal'].sum()
fevbc = despesasbotijao.loc[(despesasbotijao['mes'] == 2) & (despesasbotijao['tabela'] == 'inpc'), 'peso_mensal'].sum()
marbc = despesasbotijao.loc[(despesasbotijao['mes'] == 3) & (despesasbotijao['tabela'] == 'inpc'), 'peso_mensal'].sum()
abrbc = despesasbotijao.loc[(despesasbotijao['mes'] == 4) & (despesasbotijao['tabela'] == 'inpc'), 'peso_mensal'].sum()
maibc = despesasbotijao.loc[(despesasbotijao['mes'] == 5) & (despesasbotijao['tabela'] == 'inpc'), 'peso_mensal'].sum()
junbc = despesasbotijao.loc[(despesasbotijao['mes'] == 6) & (despesasbotijao['tabela'] == 'inpc'), 'peso_mensal'].sum()
julbc = despesasbotijao.loc[(despesasbotijao['mes'] == 7) & (despesasbotijao['tabela'] == 'inpc'), 'peso_mensal'].sum()
agobc = despesasbotijao.loc[(despesasbotijao['mes'] == 8) & (despesasbotijao['tabela'] == 'inpc'), 'peso_mensal'].sum()
setbc = despesasbotijao.loc[(despesasbotijao['mes'] == 9) & (despesasbotijao['tabela'] == 'inpc'), 'peso_mensal'].sum()
outbc = despesasbotijao.loc[(despesasbotijao['mes'] == 10) & (despesasbotijao['tabela'] == 'inpc'), 'peso_mensal'].sum()
novbc = despesasbotijao.loc[(despesasbotijao['mes'] == 11) & (despesasbotijao['tabela'] == 'inpc'), 'peso_mensal'].sum()
dezbc = despesasbotijao.loc[(despesasbotijao['mes'] == 12) & (despesasbotijao['tabela'] == 'inpc'), 'peso_mensal'].sum()

# %%
janea = despesasencanado.loc[(despesasencanado['mes'] == 1) & (despesasencanado['tabela'] == 'ipca'), 'peso_mensal'].sum()
fevea = despesasencanado.loc[(despesasencanado['mes'] == 2) & (despesasencanado['tabela'] == 'ipca'), 'peso_mensal'].sum()
marea = despesasencanado.loc[(despesasencanado['mes'] == 3) & (despesasencanado['tabela'] == 'ipca'), 'peso_mensal'].sum()
abrea = despesasencanado.loc[(despesasencanado['mes'] == 4) & (despesasencanado['tabela'] == 'ipca'), 'peso_mensal'].sum()
maiea = despesasencanado.loc[(despesasencanado['mes'] == 5) & (despesasencanado['tabela'] == 'ipca'), 'peso_mensal'].sum()
junea = despesasencanado.loc[(despesasencanado['mes'] == 6) & (despesasencanado['tabela'] == 'ipca'), 'peso_mensal'].sum()
julea = despesasencanado.loc[(despesasencanado['mes'] == 7) & (despesasencanado['tabela'] == 'ipca'), 'peso_mensal'].sum()
agoea = despesasencanado.loc[(despesasencanado['mes'] == 8) & (despesasencanado['tabela'] == 'ipca'), 'peso_mensal'].sum()
setea = despesasencanado.loc[(despesasencanado['mes'] == 9) & (despesasencanado['tabela'] == 'ipca'), 'peso_mensal'].sum()
outea = despesasencanado.loc[(despesasencanado['mes'] == 10) & (despesasencanado['tabela'] == 'ipca'), 'peso_mensal'].sum()
novea = despesasencanado.loc[(despesasencanado['mes'] == 11) & (despesasencanado['tabela'] == 'ipca'), 'peso_mensal'].sum()
dezea = despesasencanado.loc[(despesasencanado['mes'] == 12) & (despesasencanado['tabela'] == 'ipca'), 'peso_mensal'].sum()

janec = despesasencanado.loc[(despesasencanado['mes'] == 1) & (despesasencanado['tabela'] == 'inpc'), 'peso_mensal'].sum()
fevec = despesasencanado.loc[(despesasencanado['mes'] == 2) & (despesasencanado['tabela'] == 'inpc'), 'peso_mensal'].sum()
marec = despesasencanado.loc[(despesasencanado['mes'] == 3) & (despesasencanado['tabela'] == 'inpc'), 'peso_mensal'].sum()
abrec = despesasencanado.loc[(despesasencanado['mes'] == 4) & (despesasencanado['tabela'] == 'inpc'), 'peso_mensal'].sum()
maiec = despesasencanado.loc[(despesasencanado['mes'] == 5) & (despesasencanado['tabela'] == 'inpc'), 'peso_mensal'].sum()
junec = despesasencanado.loc[(despesasencanado['mes'] == 6) & (despesasencanado['tabela'] == 'inpc'), 'peso_mensal'].sum()
julec = despesasencanado.loc[(despesasencanado['mes'] == 7) & (despesasencanado['tabela'] == 'inpc'), 'peso_mensal'].sum()
agoec = despesasencanado.loc[(despesasencanado['mes'] == 8) & (despesasencanado['tabela'] == 'inpc'), 'peso_mensal'].sum()
setec = despesasencanado.loc[(despesasencanado['mes'] == 9) & (despesasencanado['tabela'] == 'inpc'), 'peso_mensal'].sum()
outec = despesasencanado.loc[(despesasencanado['mes'] == 10) & (despesasencanado['tabela'] == 'inpc'), 'peso_mensal'].sum()
novec = despesasencanado.loc[(despesasencanado['mes'] == 11) & (despesasencanado['tabela'] == 'inpc'), 'peso_mensal'].sum()
dezec = despesasencanado.loc[(despesasencanado['mes'] == 12) & (despesasencanado['tabela'] == 'inpc'), 'peso_mensal'].sum()

# %%
smjan = smdrop.loc[smdrop['Data'] == 2021.01, 'Salário mínimo vigente - R$ - Ministério da Economia- Outras (Min. Economia/Outras) - MTE12_SALMIN12'].sum()
smfev = smdrop.loc[smdrop['Data'] == 2021.02, 'Salário mínimo vigente - R$ - Ministério da Economia- Outras (Min. Economia/Outras) - MTE12_SALMIN12'].sum()
smmai = smdrop.loc[smdrop['Data'] == 2021.03, 'Salário mínimo vigente - R$ - Ministério da Economia- Outras (Min. Economia/Outras) - MTE12_SALMIN12'].sum()
smabr = smdrop.loc[smdrop['Data'] == 2021.04, 'Salário mínimo vigente - R$ - Ministério da Economia- Outras (Min. Economia/Outras) - MTE12_SALMIN12'].sum()
smmar = smdrop.loc[smdrop['Data'] == 2021.05, 'Salário mínimo vigente - R$ - Ministério da Economia- Outras (Min. Economia/Outras) - MTE12_SALMIN12'].sum()
smjun = smdrop.loc[smdrop['Data'] == 2021.06, 'Salário mínimo vigente - R$ - Ministério da Economia- Outras (Min. Economia/Outras) - MTE12_SALMIN12'].sum()
smjul = smdrop.loc[smdrop['Data'] == 2021.07, 'Salário mínimo vigente - R$ - Ministério da Economia- Outras (Min. Economia/Outras) - MTE12_SALMIN12'].sum()
smago = smdrop.loc[smdrop['Data'] == 2021.08, 'Salário mínimo vigente - R$ - Ministério da Economia- Outras (Min. Economia/Outras) - MTE12_SALMIN12'].sum()
smset = smdrop.loc[smdrop['Data'] == 2021.09, 'Salário mínimo vigente - R$ - Ministério da Economia- Outras (Min. Economia/Outras) - MTE12_SALMIN12'].sum()
smout = smdrop.loc[smdrop['Data'] == 2021.10, 'Salário mínimo vigente - R$ - Ministério da Economia- Outras (Min. Economia/Outras) - MTE12_SALMIN12'].sum()
smnov = smdrop.loc[smdrop['Data'] == 2021.11, 'Salário mínimo vigente - R$ - Ministério da Economia- Outras (Min. Economia/Outras) - MTE12_SALMIN12'].sum()
smdez = smdrop.loc[smdrop['Data'] == 2021.12, 'Salário mínimo vigente - R$ - Ministério da Economia- Outras (Min. Economia/Outras) - MTE12_SALMIN12'].sum()

# %%
porcentagemtotal = pd.DataFrame({'mes':['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez', 'jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez'],
                                'tabela':['ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'ipca', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc', 'inpc'],
                                'peso_gas_encanado':[janea, fevea, marea, abrea, maiea, junea, julea, agoea, setea, outea, novea, dezea, janec, fevec, marec, abrec, maiec, junec, julec, agoec, setec, outec, novec, dezec],
                                'peso_gas_botijao':[janba, fevba, marba, abrba, maiba, junba, julba, agoba, setba, outba, novba, dezba, janbc, fevbc, marbc, abrbc, maibc, junbc, julbc, agobc, setbc, outbc, novbc, dezbc],
                                'sm_vigente':[smjan, smfev, smmar, smabr, smmai, smjun, smjul, smago, smset, smout, smnov, smdez, smjan, smfev, smmar, smabr, smmai, smjun, smjul, smago, smset, smout, smnov, smdez]})
porcentagemtotal.head(24)
# Out:
#     mes tabela  peso_gas_encanado  peso_gas_botijao  sm_vigente
# 0   jan   ipca            58.5682           59.5534      1100.0
# 1   fev   ipca            58.3121           59.3299      1100.0
# 2   mar   ipca            58.0983           59.1373      1100.0
# 3   abr   ipca            57.5806           58.6663      1100.0
# 4   mai   ipca            57.6498           58.7457      1100.0
# 5   jun   ipca            57.5351           58.6310      1100.0
# 6   jul   ipca            57.5414           58.6438      1100.0
# 7   ago   ipca            57.6585           58.8012      1100.0
# 8   set   ipca            57.5115           58.6719      1100.0
# 9   out   ipca            57.5850           58.7817      1100.0
# 10  nov   ipca            57.5172           58.7481      1100.0
# 11  dez   ipca            57.0452           58.2906      1100.0
# 12  jan   inpc            64.3943           65.9505      1100.0
# 13  fev   inpc            64.1515           65.7534      1100.0
# ...

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(16,7))
encanadofig = sns.lineplot(data=porcentagemtotal, x='mes', y='peso_gas_encanado', hue='tabela', style='tabela',  markers=True, dashes=False, ax=ax1).set(yticks=range(55,70))
botijaofig = sns.lineplot(data=porcentagemtotal, x='mes', y='peso_gas_botijao', hue='tabela', style='tabela',  markers=True, dashes=False, ax=ax2).set(yticks=range(55,70))

# %%
porcentagemtotal['sm_peso_botijao'] = (porcentagemtotal['peso_gas_botijao'] / 100) * porcentagemtotal['sm_vigente']
porcentagemtotal['sm_peso_encanado'] = (porcentagemtotal['peso_gas_encanado'] / 100) * porcentagemtotal['sm_vigente']
porcentagemtotal.head()
# Out:
#    mes tabela  peso_gas_encanado  peso_gas_botijao  sm_vigente  \
# 0  jan   ipca            58.5682           59.5534      1100.0
# 1  fev   ipca            58.3121           59.3299      1100.0
# 2  mar   ipca            58.0983           59.1373      1100.0
# 3  abr   ipca            57.5806           58.6663      1100.0
# 4  mai   ipca            57.6498           58.7457      1100.0
#
#    sm_peso_botijao  sm_peso_encanado
# 0         655.0874          644.2502
# 1         652.6289          641.4331
# 2         650.5103          639.0813
# 3         645.3293          633.3866
# 4         646.2027          634.1478

# %%
f, (ax1) = plt.subplots(figsize=(9,9))
ax2 = ax1.twinx()
ax2.grid(False)
smfig = sns.barplot(data=porcentagemtotal, x='mes', y='sm_vigente', ax=ax1).set(yticks=(0,100,200,300,400,500,600,700,800,900,1000,1100,1200))
botijaopesofig = sns.lineplot(data=porcentagemtotal, x='mes', y='sm_peso_botijao', hue='tabela', marker='o', dashes=False, ax=ax2).set(yticks=(0,100,200,300,400,500,600,700,800,900,1000,1100,1200))

# %%
f, (ax1) = plt.subplots(figsize=(9,9))
ax2 = ax1.twinx()
ax2.grid(False)
smfig = sns.barplot(data=porcentagemtotal, x='mes', y='sm_vigente', ax=ax1).set(yticks=(0,100,200,300,400,500,600,700,800,900,1000,1100,1200))
canopesofig = sns.lineplot(data=porcentagemtotal, x='mes', y='sm_peso_encanado', hue='tabela', marker='o', dashes=False, ax=ax2).set(yticks=(0,100,200,300,400,500,600,700,800,900,1000,1100,1200))

# %%
despesaipcaencanado = (porcentagemtotal.loc[porcentagemtotal['tabela'] == 'ipca', 'sm_peso_encanado'].sum()) / 12
despesainpcencanado = (porcentagemtotal.loc[porcentagemtotal['tabela'] == 'inpc', 'sm_peso_encanado'].sum()) / 12
despesaipcabutijao = (porcentagemtotal.loc[porcentagemtotal['tabela'] == 'ipca', 'sm_peso_botijao'].sum()) / 12
despesainpcbutijao = (porcentagemtotal.loc[porcentagemtotal['tabela'] == 'inpc', 'sm_peso_botijao'].sum()) / 12
sm_ano = (smjan + smfev + smmar + smabr + smmai + smjun + smjul + smago + smset + smout + smnov + smdez) / 12

# %%
relrpc = indsocdrop.drop(['Porcentagem de pessoas com renda domiciliar per capita igual ou inferior a meio salário mínimo'], axis=1)
relrpc["despesas_totais_ipca_encanado"] = (despesaipcaencanado)
relrpc["despesas_totais_inpc_encanado"] = (despesainpcencanado)
relrpc["despesas_totais_ipca_botijao"] = (despesaipcabutijao)
relrpc["despesas_totais_inpc_botijao"] = (despesainpcbutijao)
relrpc["salário_mínimo_anual"] = (sm_ano)

# %%
relrpc.head()
# Out:
#   Nome da UF   Ano  Renda per capita  despesas_totais_ipca_encanado  \
# 0   Rondônia  2021            552.08                     634.885992
# 1       Acre  2021            477.19                     634.885992
# 2   Amazonas  2021            433.18                     634.885992
# 3    Roraima  2021            562.36                     634.885992
# 4       Pará  2021            461.93                     634.885992
#
#    despesas_totais_inpc_encanado  despesas_totais_ipca_botijao  \
# 0                      698.10455                    647.167492
# 1                      698.10455                    647.167492
# 2                      698.10455                    647.167492
# 3                      698.10455                    647.167492
# 4                      698.10455                    647.167492
#
#    despesas_totais_inpc_botijao  salário_mínimo_anual
# 0                    717.385992                1100.0
# 1                    717.385992                1100.0
# ...

# %%
#Gráficos comparando a relação entre a renda per capita em cada estado e o custo de despesas em relação ao salário mínimo utilizando o cenário do gás encanado
f, (ax1, ax3) = plt.subplots(1, 2, figsize=(24,9))
ax2 = ax1.twinx()
ax2.grid(False)
ax4 = ax3.twinx()
ax4.grid(False)
rpcfig = sns.barplot(data=relrpc, x='Nome da UF', y='Renda per capita', ax=ax1).set(yticks=(0,100,300,500,700,900,1100,1300,1500))
canoipcafig = sns.lineplot(data=relrpc, x='Nome da UF', y='despesas_totais_ipca_encanado', marker='o', dashes=False, ax=ax2).set(yticks=(0,100,300,500,700,900,1100,1300,1500))
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=65, horizontalalignment='right')
rpc2fig = sns.barplot(data=relrpc, x='Nome da UF', y='Renda per capita', ax=ax3).set(yticks=(0,100,300,500,700,900,1100,1300,1500))
canoinpcfig = sns.lineplot(data=relrpc, x='Nome da UF', y='despesas_totais_inpc_encanado', marker='o', dashes=False, ax=ax4).set(yticks=(0,100,300,500,700,900,1100,1300,1500))
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=65, horizontalalignment='right')
plt.show()

# %%
#Gráficos comparando a relação entre a renda per capita em cada estado e o custo de despesas em relação ao salário mínimo utilizando o cenário do botijão de gás
f, (ax1, ax3) = plt.subplots(1, 2, figsize=(24,9))
ax2 = ax1.twinx()
ax2.grid(False)
ax4 = ax3.twinx()
ax4.grid(False)
rpcfig = sns.barplot(data=relrpc, x='Nome da UF', y='Renda per capita', ax=ax1).set(yticks=(0,100,300,500,700,900,1100,1300,1500))
botijaoipcafig = sns.lineplot(data=relrpc, x='Nome da UF', y='despesas_totais_ipca_botijao', marker='o', dashes=False, ax=ax2).set(yticks=(0,100,300,500,700,900,1100,1300,1500))
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=65, horizontalalignment='right')
rpc2fig = sns.barplot(data=relrpc, x='Nome da UF', y='Renda per capita', ax=ax3).set(yticks=(0,100,300,500,700,900,1100,1300,1500))
botijaoinpcfig = sns.lineplot(data=relrpc, x='Nome da UF', y='despesas_totais_inpc_botijao', marker='o', dashes=False, ax=ax4).set(yticks=(0,100,300,500,700,900,1100,1300,1500))
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=65, horizontalalignment='right')
plt.show()

# %% [markdown]
# ## Especulação de cenários

# %% [markdown]
# #### Cenário que utiliza o sálario minimo com seu objetivo original: prover o sustento de uma casa com 4 residentes

# %%
porcentagemtotal['botijao_4_pessoas'] = (porcentagemtotal['sm_peso_botijao'] * 4)
porcentagemtotal['encanado_4_pessoas'] = (porcentagemtotal['sm_peso_encanado'] * 4)
porcentagemtotal.head()
# Out:
#    mes tabela  peso_gas_encanado  peso_gas_botijao  sm_vigente  \
# 0  jan   ipca            58.5682           59.5534      1100.0
# 1  fev   ipca            58.3121           59.3299      1100.0
# 2  mar   ipca            58.0983           59.1373      1100.0
# 3  abr   ipca            57.5806           58.6663      1100.0
# 4  mai   ipca            57.6498           58.7457      1100.0
#
#    sm_peso_botijao  sm_peso_encanado  botijao_4_pessoas  encanado_4_pessoas
# 0         655.0874          644.2502          2620.3496           2577.0008
# 1         652.6289          641.4331          2610.5156           2565.7324
# 2         650.5103          639.0813          2602.0412           2556.3252
# 3         645.3293          633.3866          2581.3172           2533.5464
# 4         646.2027          634.1478          2584.8108           2536.5912

# %%
f, (ax1, ax3) = plt.subplots(1, 2, figsize=(24,8))
ax2 = ax1.twinx()
ax2.grid(False)
smfig = sns.barplot(data=porcentagemtotal, x='mes', y='sm_vigente', ax=ax1).set(yticks=(0,500,1000,1500,2000,2500,3000))
cano4fig = sns.lineplot(data=porcentagemtotal, x='mes', y='encanado_4_pessoas', hue='tabela', marker='o', dashes=False, ax=ax2).set(yticks=(0,500,1000,1500,2000,2500,3000))
ax4 = ax3.twinx()
ax4.grid(False)
smfig = sns.barplot(data=porcentagemtotal, x='mes', y='sm_vigente', ax=ax3).set(yticks=(0,500,1000,1500,2000,2500,3000))
botijao4fig = sns.lineplot(data=porcentagemtotal, x='mes', y='botijao_4_pessoas', hue='tabela', marker='o', dashes=False, ax=ax4).set(yticks=(0,500,1000,1500,2000,2500,3000))

# %% [markdown]
# #### Cenário onde uma residência com 4 pessoas é sustentada por 2 salários mínimos

# %%
porcentagemtotal['2_sm'] = (porcentagemtotal['sm_vigente'] * 2)
porcentagemtotal.head()
# Out:
#    mes tabela  peso_gas_encanado  peso_gas_botijao  sm_vigente  \
# 0  jan   ipca            58.5682           59.5534      1100.0
# 1  fev   ipca            58.3121           59.3299      1100.0
# 2  mar   ipca            58.0983           59.1373      1100.0
# 3  abr   ipca            57.5806           58.6663      1100.0
# 4  mai   ipca            57.6498           58.7457      1100.0
#
#    sm_peso_botijao  sm_peso_encanado  botijao_4_pessoas  encanado_4_pessoas  \
# 0         655.0874          644.2502          2620.3496           2577.0008
# 1         652.6289          641.4331          2610.5156           2565.7324
# 2         650.5103          639.0813          2602.0412           2556.3252
# 3         645.3293          633.3866          2581.3172           2533.5464
# 4         646.2027          634.1478          2584.8108           2536.5912
#
#      2_sm
# 0  2200.0
# 1  2200.0
# 2  2200.0
# 3  2200.0
# 4  2200.0

# %%
f, (ax1, ax3) = plt.subplots(1, 2, figsize=(24,8))
ax2 = ax1.twinx()
ax2.grid(False)
sm2fig = sns.barplot(data=porcentagemtotal, x='mes', y='2_sm', ax=ax1).set(yticks=(0,500,1000,1500,2000,2500,3000))
cano4fig = sns.lineplot(data=porcentagemtotal, x='mes', y='encanado_4_pessoas', hue='tabela', marker='o', dashes=False, ax=ax2).set(yticks=(0,500,1000,1500,2000,2500,3000))
ax4 = ax3.twinx()
ax4.grid(False)
sm2fig = sns.barplot(data=porcentagemtotal, x='mes', y='2_sm', ax=ax3).set(yticks=(0,500,1000,1500,2000,2500,3000))
botijao4fig = sns.lineplot(data=porcentagemtotal, x='mes', y='botijao_4_pessoas', hue='tabela', marker='o', dashes=False, ax=ax4).set(yticks=(0,500,1000,1500,2000,2500,3000))

# %% [markdown]
# #### Cenário levando em conta as rendas per capita estaduais e utilizando uma residência com 4 pessoas

# %%
relrpc['4_pessoas'] = (relrpc['Renda per capita'] * 4)
relrpc['encanado_ipca_4_pessoas'] = (relrpc['despesas_totais_ipca_encanado'] * 4)
relrpc['encanado_inpc_4_pessoas'] = (relrpc['despesas_totais_inpc_encanado'] * 4)
relrpc['botijao_ipca_4_pessoas'] = (relrpc['despesas_totais_ipca_botijao'] * 4)
relrpc['botijao_inpc_4_pessoas'] = (relrpc['despesas_totais_inpc_botijao'] * 4)
relrpc.head()
# Out:
#   Nome da UF   Ano  Renda per capita  despesas_totais_ipca_encanado  \
# 0   Rondônia  2021            552.08                     634.885992
# 1       Acre  2021            477.19                     634.885992
# 2   Amazonas  2021            433.18                     634.885992
# 3    Roraima  2021            562.36                     634.885992
# 4       Pará  2021            461.93                     634.885992
#
#    despesas_totais_inpc_encanado  despesas_totais_ipca_botijao  \
# 0                      698.10455                    647.167492
# 1                      698.10455                    647.167492
# 2                      698.10455                    647.167492
# 3                      698.10455                    647.167492
# 4                      698.10455                    647.167492
#
#    despesas_totais_inpc_botijao  salário_mínimo_anual  4_pessoas  \
# 0                    717.385992                1100.0    2208.32
# ...

# %%
f, (ax1, ax3) = plt.subplots(1, 2, figsize=(24,9))
ax2 = ax1.twinx()
ax2.grid(False)
ax4 = ax3.twinx()
ax4.grid(False)
rpcfig = sns.barplot(data=relrpc, x='Nome da UF', y='4_pessoas', ax=ax1).set(yticks=(0,1000,2000,3000,4000,5000,6000))
canoipcafig = sns.lineplot(data=relrpc, x='Nome da UF', y='encanado_ipca_4_pessoas', marker='o', dashes=False, ax=ax2).set(yticks=(0,1000,2000,3000,4000,5000,6000))
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=65, horizontalalignment='right')
rpc2fig = sns.barplot(data=relrpc, x='Nome da UF', y='4_pessoas', ax=ax3).set(yticks=(0,1000,2000,3000,4000,5000,6000))
canoinpcfig = sns.lineplot(data=relrpc, x='Nome da UF', y='encanado_inpc_4_pessoas', marker='o', dashes=False, ax=ax4).set(yticks=(0,1000,2000,3000,4000,5000,6000))
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=65, horizontalalignment='right')
plt.show()

# %%
f, (ax1, ax3) = plt.subplots(1, 2, figsize=(24,9))
ax2 = ax1.twinx()
ax2.grid(False)
ax4 = ax3.twinx()
ax4.grid(False)
rpcfig = sns.barplot(data=relrpc, x='Nome da UF', y='4_pessoas', ax=ax1).set(yticks=(0,1000,2000,3000,4000,5000,6000))
botijaoipcafig = sns.lineplot(data=relrpc, x='Nome da UF', y='botijao_ipca_4_pessoas', marker='o', dashes=False, ax=ax2).set(yticks=(0,1000,2000,3000,4000,5000,6000))
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=65, horizontalalignment='right')
rpc2fig = sns.barplot(data=relrpc, x='Nome da UF', y='4_pessoas', ax=ax3).set(yticks=(0,1000,2000,3000,4000,5000,6000))
botijaoinpcfig = sns.lineplot(data=relrpc, x='Nome da UF', y='botijao_inpc_4_pessoas', marker='o', dashes=False, ax=ax4).set(yticks=(0,1000,2000,3000,4000,5000,6000))
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=65, horizontalalignment='right')
plt.show()
